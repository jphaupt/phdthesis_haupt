# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt('FCIMStats_10Bohr', skip_header=6873) # 10 trial determinants

# %%
plt.plot(data[:,0], data[:,22], label='HF Projected Energy')
plt.plot(data[:,0], data[:,33]/data[:,34], label='Trial Projected Energy')
plt.legend()
plt.xlabel('Imaginary Time')
plt.ylabel('Energy (Hartree)')
plt.savefig('trial_v_projE.pdf')
# Out:
# /tmp/ipykernel_17435/4141802222.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.plot(data[:,0], data[:,33]/data[:,34], label='Trial Projected Energy')
